# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

train_df = pd.read_csv("train.csv")
test_df = pd.read_csv("test.csv")

# %%
train_df.sample(5)
# Out:
#      PassengerId  Survived  Pclass  \
# 482          483         0       3
# 536          537         0       1
# 747          748         1       2
# 774          775         1       2
# 715          716         0       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 482                    Rouse, Mr. Richard Henry    male  50.0      0      0
# 536           Butt, Major. Archibald Willingham    male  45.0      0      0
# 747                       Sinkkonen, Miss. Anna  female  30.0      0      0
# 774       Hocking, Mrs. Elizabeth (Eliza Needs)  female  54.0      1      3
# 715  Soholt, Mr. Peter Andreas Lauritz Andersen    male  19.0      0      0
#
#        Ticket   Fare  Cabin Embarked
# 482  A/5 3594   8.05    NaN        S
# 536    113050  26.55    B38        S
# 747    250648  13.00    NaN        S
# 774     29105  23.00    NaN        S
# 715    348124   7.65  F G73        S

# %%
test_df.sample(5)
# Out:
#      PassengerId  Pclass                                            Name  \
# 49           941       3  Coutts, Mrs. William (Winnie Minnie" Treanor)"
# 125         1017       3                        Cribb, Miss. Laura Alice
# 190         1082       2                            Angle, Mr. William A
# 416         1308       3                             Ware, Mr. Frederick
# 23           915       1                 Williams, Mr. Richard Norris II
#
#         Sex   Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# 49   female  36.0      0      2  C.A. 37671  15.9000   NaN        S
# 125  female  17.0      0      1      371362  16.1000   NaN        S
# 190    male  34.0      1      0      226875  26.0000   NaN        S
# 416    male   NaN      0      0      359309   8.0500   NaN        S
# 23     male  21.0      0      1    PC 17597  61.3792   NaN        C

# %%
train_df.shape, test_df.shape
# Out:
# ((891, 12), (418, 11))

# %%
train_df.describe([0.01, 0.1, 0.25, 0.5, 0.75, 0.9, 0.99])
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 1%        9.900000    0.000000    1.000000    1.000000    0.000000
# 10%      90.000000    0.000000    1.000000   14.000000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# 90%     802.000000    1.000000    3.000000   50.000000    1.000000
# 99%     882.100000    1.000000    3.000000   65.870000    5.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# ...

# %%
print(train_df.info())
print('*'*100)
print(test_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# None
# ****************************************************************************************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
# ...

# %%
train_df.describe(include=["O"])
# Out:
#                        Name   Sex Ticket    Cabin Embarked
# count                   891   891    891      204      889
# unique                  891     2    681      147        3
# top     Svensson, Mr. Johan  male   1601  B96 B98        S
# freq                      1   577      7        4      644

# %%
train_df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
test_df.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %% [markdown]
# # Univariate Analysis

# %%
cols = list(train_df.select_dtypes(include=["O"]).columns)
cols.remove("Cabin")
cols.remove("Ticket")
cols.remove("Name")
cols.append("Parch")
cols.append("SibSp")
cols.append("Pclass")
for col in cols:
    plt.figure()
    plt.title(col, fontsize=18)
    sns.countplot(data=train_df, x=col, hue="Survived");

# %%
num_cols = list(train_df.select_dtypes(exclude=["O"]).columns)
num_cols.remove("Parch")
num_cols.remove("SibSp")
num_cols.remove("Survived")
num_cols.remove("PassengerId")
num_cols.remove("Pclass")

for col in num_cols:
    plt.figure()
    plt.title(col, fontsize=18)
    sns.boxplot(train_df[col]);
    
for col in num_cols:
    plt.figure()
    plt.title(col, fontsize=18)
    sns.histplot(train_df[col], kde=True, bins=15);
# Out:
# /Users/tomfujii/anaconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /Users/tomfujii/anaconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /Users/tomfujii/anaconda3/lib/python3.7/site-packages/matplotlib/cbook/__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# ...

# %% [markdown]
# # Bi-variate Analysis

# %%
train_df[["Survived", "SibSp"]].groupby("SibSp", as_index=False).mean().sort_values(by="Survived", ascending=False)
# Out:
#    SibSp  Survived
# 1      1  0.535885
# 2      2  0.464286
# 0      0  0.345395
# 3      3  0.250000
# 4      4  0.166667
# 5      5  0.000000
# 6      8  0.000000

# %%
train_df[["Survived", "Parch"]].groupby("Parch", as_index=False).mean().sort_values(by="Survived", ascending=False)
# Out:
#    Parch  Survived
# 3      3  0.600000
# 1      1  0.550847
# 2      2  0.500000
# 0      0  0.343658
# 5      5  0.200000
# 4      4  0.000000
# 6      6  0.000000

# %%
train_df[["Survived", "Embarked"]].groupby("Embarked", as_index=False).mean().sort_values("Survived", ascending=False)
# Out:
#   Embarked  Survived
# 0        C  0.553571
# 1        Q  0.389610
# 2        S  0.336957

# %%
train_df[["Survived", "Sex"]].groupby("Sex", as_index=False).mean().sort_values("Survived", ascending=False)
# Out:
#       Sex  Survived
# 0  female  0.742038
# 1    male  0.188908

# %%
g = sns.FacetGrid(train_df, col="Survived")
g.map(plt.hist, "Age", bins=20);
# Out:
# /Users/tomfujii/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:829: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /Users/tomfujii/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:830: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
g = sns.FacetGrid(train_df, col="Survived", row="Pclass")
g.map(plt.hist, "Age", bins=20);
# Out:
# /Users/tomfujii/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:829: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /Users/tomfujii/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:830: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
g = sns.FacetGrid(train_df, row="Embarked")
g.map(sns.pointplot, "Pclass", "Survived", "Sex");
g.add_legend()
# Out:
# /Users/tomfujii/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:643: UserWarning: Using the pointplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)
# /Users/tomfujii/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:648: UserWarning: Using the pointplot function without specifying `hue_order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
train_df = train_df.drop(["Ticket", "Cabin"], axis=1)
test_df = test_df.drop(["Ticket", "Cabin"], axis=1)

# %%
combine = [train_df, test_df]

for dataset in combine:
    dataset['Title'] = dataset.Name.str.extract(' ([A-Za-z]+)\.', expand=False)

pd.crosstab(train_df['Title'], train_df['Sex'])
# Out:
# Sex       female  male
# Title
# Capt           0     1
# Col            0     2
# Countess       1     0
# Don            0     1
# Dr             1     6
# Jonkheer       0     1
# Lady           1     0
# Major          0     2
# Master         0    40
# Miss         182     0
# Mlle           2     0
# Mme            1     0
# Mr             0   517
# Mrs          125     0
# Ms             1     0
# Rev            0     6
# Sir            0     1

# %%
for dataset in combine:
    dataset['Title'] = dataset['Title'].replace(['Lady', 'Countess','Capt', 'Col',\
                                                 'Don', 'Dr', 'Major', 'Rev', 'Sir', 'Jonkheer', 'Dona'], 'Rare')

    dataset['Title'] = dataset['Title'].replace('Mlle', 'Miss')
    dataset['Title'] = dataset['Title'].replace('Ms', 'Miss')
    dataset['Title'] = dataset['Title'].replace('Mme', 'Mrs')
    
train_df[['Title', 'Survived']].groupby(['Title'], as_index=False).mean()
# Out:
#     Title  Survived
# 0  Master  0.575000
# 1    Miss  0.702703
# 2      Mr  0.156673
# 3     Mrs  0.793651
# 4    Rare  0.347826

# %%
from sklearn import preprocessing



cols = ["Title", "Sex",]
for col in cols:
    le = preprocessing.LabelEncoder()
    train_df[col] = le.fit_transform(train_df[col])
    test_df[col] = le.transform(test_df[col])
    print(col, le.classes_)
# Out:
# Title ['Master' 'Miss' 'Mr' 'Mrs' 'Rare']
# Sex ['female' 'male']

# %%
combine = [train_df, test_df]

guess_ages = np.zeros((2, 3))
for dataset in combine:
    for i in range(0, 2):
        for j in range(0, 3):
            guess_df = dataset[(dataset['Sex'] == i) & \
                                  (dataset['Pclass'] == j+1)]['Age'].dropna()

            # age_mean = guess_df.mean()
            # age_std = guess_df.std()
            # age_guess = rnd.uniform(age_mean - age_std, age_mean + age_std)

            age_guess = guess_df.median()

            # Convert random age float to nearest .5 age
            guess_ages[i,j] = int( age_guess/0.5 + 0.5 ) * 0.5
            
    for i in range(0, 2):
        for j in range(0, 3):
            dataset.loc[ (dataset.Age.isnull()) & (dataset.Sex == i) & (dataset.Pclass == j+1),\
                    'Age'] = guess_ages[i,j]

    dataset['Age'] = dataset['Age'].astype(int)

train_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex  Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1   22      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0   38      1      0
# 2                             Heikkinen, Miss. Laina    0   26      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0   35      1      0
# 4                           Allen, Mr. William Henry    1   35      0      0
#
#       Fare Embarked  Title
# 0   7.2500        S      2
# 1  71.2833        C      3
# 2   7.9250        S      1
# 3  53.1000        S      3
# 4   8.0500        S      2

# %%
dataset["Sex"]
# Out:
# 0      1
# 1      0
# 2      1
# 3      1
# 4      0
#       ..
# 413    1
# 414    0
# 415    1
# 416    1
# 417    1
# Name: Sex, Length: 418, dtype: int64
